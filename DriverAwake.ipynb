# %%
pip install keras
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pygame
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install opencv-contrib-python

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# ...

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# fatal: destination path 'yolov5' already exists and is not an empty directory.

# %%
# !cd yolov5
# !pip install -r https://github.com/ultralytics/yolov5/raw/master/requirements.txt

# %%
pip install opencv-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
from matplotlib import pyplot as plt

# %%
# !git clone https://github.com/tzutalin/labelImg
# Out:
# fatal: destination path 'labelImg' already exists and is not an empty directory.

# %%
model1 = torch.hub.load('ultralytics/yolov5','yolov5s')
# Out:
# Using cache found in C:\Users\anush/.cache\torch\hub\ultralytics_yolov5_master
# YOLOv5  2023-1-4 Python-3.9.13 torch-1.13.1+cu117 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients
# Adding AutoShape...

# %%
from keras.models import load_model

# %%
# !git clone https://github.com/16102/DriverAwakeAssist
# !cd DriverAwakeAssist
# Out:
# Cloning into 'DriverAwakeAssist'...

# %%
model = load_model('DriverAwakeAssist/cnncat2.h5')

# %%
import cv2
import os


import numpy as np
from pygame import mixer
import time

mixer.init()
sound = mixer.Sound('C:\\Users\\anush\\Desktop\\Driver_safety\\Drowsiness detection\\Drowsiness detection\\alarm.wav')

face = cv2.CascadeClassifier('C:\\Users\\anush\\Desktop\\Driver_safety\\Drowsiness detection\\Drowsiness detection\\haar cascade files\\haarcascade_frontalface_alt.xml')
leye = cv2.CascadeClassifier('C:\\Users\\anush\\Desktop\\Driver_safety\\Drowsiness detection\\Drowsiness detection\\haar cascade files\\haarcascade_lefteye_2splits.xml')
reye = cv2.CascadeClassifier('C:\\Users\\anush\\Desktop\\Driver_safety\\Drowsiness detection\\Drowsiness detection\\haar cascade files\\haarcascade_righteye_2splits.xml')

lbl=['Close','Open']


path = os.getcwd()
cap = cv2.VideoCapture(0)
font = cv2.FONT_HERSHEY_COMPLEX_SMALL
count=0
score=0
thicc=2
rpred=[99]
lpred=[99]

while(True):
    ret, frame = cap.read()
    results = model1(frame)
    height,width = frame.shape[:2]

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    faces = face.detectMultiScale(gray,minNeighbors=5,scaleFactor=1.1,minSize=(25,25))
    left_eye = leye.detectMultiScale(gray)
    right_eye = reye.detectMultiScale(gray)

    cv2.rectangle(frame, (0,height-50) , (200,height) , (0,0,0) , thickness=cv2.FILLED )

    for (x,y,w,h) in faces:
        cv2.rectangle(frame, (x,y) , (x+w,y+h) , (100,100,100) , 1 )

    for (x,y,w,h) in right_eye:
        r_eye=frame[y:y+h,x:x+w]
        count=count+1
        r_eye = cv2.cvtColor(r_eye,cv2.COLOR_BGR2GRAY)
        r_eye = cv2.resize(r_eye,(24,24))
        r_eye= r_eye/255
        r_eye= r_eye.reshape(24,24,-1)
        r_eye = np.expand_dims(r_eye,axis=0)
        #rpred = model.predict_classes(r_eye)
        rpred=model.predict(r_eye)
        classes_y=np.argmax(rpred,axis=1)
        if(classes_y[0]==1):
            lbl='Open'
        if(classes_y[0]==0):
            lbl='Closed'
        break

    for (x,y,w,h) in left_eye:
        l_eye=frame[y:y+h,x:x+w]
        count=count+1
        l_eye = cv2.cvtColor(l_eye,cv2.COLOR_BGR2GRAY)
        l_eye = cv2.resize(l_eye,(24,24))
        l_eye= l_eye/255
        l_eye=l_eye.reshape(24,24,-1)
        l_eye = np.expand_dims(l_eye,axis=0)
        #lpred = model.predict_classes(l_eye)
        lpred=model.predict(l_eye)
        classes_x=np.argmax(lpred,axis=1)
        if(classes_x[0]==1):
            lbl='Open'
        if(classes_x[0]==0):
            lbl='Closed'
        break

    if(classes_x[0]==0 and classes_y[0]==0):
        score=score+1
        cv2.putText(frame,"Closed",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    # if(rpred[0]==1 or lpred[0]==1):
    else:
        score=score-1
        cv2.putText(frame,"Open",(10,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)

    if(score<0):
        score=0
    cv2.putText(frame,'Score:'+str(score),(100,height-20), font, 1,(255,255,255),1,cv2.LINE_AA)
    if(score>15):
        #person is feeling sleepy so we beep the alarm
        cv2.imwrite(os.path.join(path,'image.jpg'),frame)
        try:
            sound.play()

        except: # isplaying = False
            pass
        if(thicc<16):
            thicc= thicc+2
        else:
            thicc=thicc-2
            if(thicc<2):
                thicc=2
        cv2.rectangle(frame,(0,0),(width,height),(0,0,255),thicc)
    
    cv2.imshow('YOLO', np.squeeze(results.render()))
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ...
# 1/1 [==============================] - 0s 20ms/step
# ...
# ...
# 1/1 [==============================] - 0s 19ms/step
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10380\483253616.py in <module>
#      28 while(True):
#      29     ret, frame = cap.read()
# ---> 30     results = model1(frame)
#      31     height,width = frame.shape[:2]
#      32
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1192         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1193                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1194             return forward_call(*input, **kwargs)
#    1195         # Do not call functions when jit is used
#    1196         full_backward_hooks, non_full_backward_hooks = [], []
#
# ...
